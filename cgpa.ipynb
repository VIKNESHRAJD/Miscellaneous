# %%
VR = [6.35, 7.17, 8.21, 8.09, 8.57]

VR = sum(VR) / len(VR)
print("CGPA:", VR)

# %%
VR = [7.56, 8.56, 10, 9.5, 9.4, 7.6, 7.7, 8.4, 9.25]

VR = sum(VR) / len(VR)
print("CGPA:", VR)
# Out:
# CGPA: 8.663333333333334
